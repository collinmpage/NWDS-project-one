# %%
#Pull Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

# %%
#Read in csv file
data = pd.read_csv("archive/Spotify_data_csv.csv")
data
# Out:
#         acousticness                                   artists  danceability  \
# 0             0.9950                       ['Carl Woitschach']         0.708
# 1             0.9940  ['Robert Schumann', 'Vladimir Horowitz']         0.379
# 2             0.6040                   ['Seweryn Goszczyński']         0.749
# 3             0.9950                      ['Francisco Canaro']         0.781
# 4             0.9900  ['Frédéric Chopin', 'Vladimir Horowitz']         0.210
# ...              ...                                       ...           ...
# 169904        0.1730                    ['DripReport', 'Tyga']         0.875
# 169905        0.0167        ['Leon Bridges', 'Terrace Martin']         0.719
# 169906        0.5380                     ['Kygo', 'Oh Wonder']         0.514
# 169907        0.0714             ['Cash Cash', 'Andy Grammer']         0.646
# 169908        0.1090                        ['Ingrid Andress']         0.512
#
# ...

# %%
#Truncate to 75 years
data_year = pd.read_csv("archive/Spotify_data_by_year.csv")
data_year

data_75 = data_year.loc[(data_year["year"] >= 1945) & (data_year["year"] <= 2020)]
data_75
# Out:
#      year  acousticness  danceability    duration_ms    energy  \
# 25   1945      0.711386      0.517856  195720.266500  0.225413
# 26   1946      0.920627      0.415141  266923.718642  0.222361
# 27   1947      0.915655      0.472104  232131.882701  0.262955
# 28   1948      0.922949      0.462736  200208.082000  0.241484
# 29   1949      0.907088      0.444031  223351.576000  0.247214
# ..    ...           ...           ...            ...       ...
# 96   2016      0.226944      0.581583  258001.186462  0.656547
# 97   2017      0.207413      0.580475  243402.249536  0.686392
# 98   2018      0.233836      0.602731  227073.140015  0.659552
# 99   2019      0.261344      0.603101  225463.326320  0.629781
# 100  2020      0.202303      0.605285  218977.482767  0.674247
#
#      instrumentalness  liveness   loudness  speechiness       tempo   valence  \
# 25           0.274928  0.203334 -16.927997     0.301714  108.256917  0.491416
# ...

# %%
#Scatterplot of acousticness vs. instrumentalness
x_values = data_75["acousticness"]
y_values = data_75["instrumentalness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot the scatter plot and linear regression
plt.scatter(x_values, y_values, facecolor="teal", edgecolor="darkslategrey")
plt.plot(x_values,regress_values,"r-", color="black")
plt.annotate(line_eq,(0.25, 1.5),fontsize=15,color="black")

#Add grid
plt.grid()

#Set titles, x and y labels
plt.title("Acousticness vs. Instrumentalness")
plt.xlabel("Acousticness")
plt.ylabel("Instrumentalness")

#Print the r-squared value
print(f"The r-squared is: {rvalue**2}")

#Save PNG of plot
plt.savefig("archive/acousticness_instrumentalness.png")

#Display scatter plot
plt.show()
# Out:
# The r-squared is: 0.35519082002312813

# %%
#Scatterplot of acousticness vs. loudness
x_values = data_75["acousticness"]
y_values = data_75["loudness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot the scatter plot and linear regression
plt.scatter(x_values, y_values, facecolor="teal", edgecolor="darkslategrey")
plt.plot(x_values,regress_values,"r-", color="black")
plt.annotate(line_eq,(0.25, 1.5),fontsize=15,color="black")

#Add grid
plt.grid()

#Set titles, x and y labels
plt.title("Acousticness vs. Loudness")
plt.xlabel("Acousticness")
plt.ylabel("Loudness")

#Print the r-squared value
print(f"The r-squared is: {rvalue**2}")

#Save PNG of plot
plt.savefig("archive/acousticness_loudness.png")

#Display scatter plot
plt.show()
# Out:
# The r-squared is: 0.8258738695850405

# %%
#Scatterplot of acousticness vs. liveness
x_values = data_75["acousticness"]
y_values = data_75["liveness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot the scatter plot and linear regression
plt.scatter(x_values, y_values, facecolor="teal", edgecolor="darkslategrey")
plt.plot(x_values,regress_values,"r-", color="black")
plt.annotate(line_eq,(0.25, 1.5),fontsize=15,color="black")

#Add grid
plt.grid()

#Set titles, x and y labels
plt.title("Acousticness vs. Liveness")
plt.xlabel("Acousticness")
plt.ylabel("Liveness")

#Print the r-squared value
print(f"The r-squared is: {rvalue**2}")

#Save PNG of plot
plt.savefig("archive/acousticness_liveness.png")

#Display scatter plot
plt.show()
# Out:
# The r-squared is: 0.0010286221454120458
